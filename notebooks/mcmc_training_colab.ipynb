# %% [markdown]
#  MCMC Training on Google Colab
#
# This notebook provides a quick setup for training Bayesian Neural Networks using SGMCMC samplers (SGLD, SGHMC, BAOA) on Google Colab.
#
# **Steps:**
# 1. Clone the repository (nanogpy_training_gpu_samplers branch)
# 2. Install required dependencies
# 3. Run the Bayesian training script with your chosen sampler
#
# **Available samplers:** sgld, sghmc, baoa

# %%
# !git clone -b nanogpy_training_gpu_samplers https://github.com/ssophiee/adl-bnn-textgen.git
# !pip install -r /content/adl-bnn-textgen/requirements.txt

# %%
# !cd adl-bnn-textgen
# !python3 scripts/bayesian_training_script.py --sampler baoa
